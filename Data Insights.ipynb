# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('/content/QVI_data.csv')

# %%
dataset.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0      175.0
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7      150.0
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6      210.0
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0      175.0
# 4          WW Original Stacked Chips 160g         1        1.9      160.0
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %% [markdown]
# # **Total Sales Revenue**

# %%
total_sales=sum(dataset['TOT_SALES'])
print(total_sales)
# Out:
# 648082.6000000718

# %% [markdown]
# # **Total no. of Customers**

# %% [markdown]
# There is not any customer column in dataset, but we can get customers by TX_ID bcoz its unique for every individual.

# %%
dataset.describe()
# Out:
#        LYLTY_CARD_NBR     STORE_NBR        TXN_ID      PROD_NBR      PROD_QTY  \
# count    87750.000000  87750.000000  87750.000000  87750.000000  87750.000000
# mean     47334.926370     47.168821  44806.625379     56.338758      1.900433
# std      25807.518969     25.812642  25859.213311     32.799983      0.349900
# min       1000.000000      1.000000      1.000000      1.000000      1.000000
# 25%      26044.000000     26.000000  22429.500000     28.000000      2.000000
# 50%      49060.000000     49.000000  44791.500000     55.000000      2.000000
# 75%      69211.750000     69.000000  67191.750000     85.000000      2.000000
# max      91102.000000    155.000000  89605.000000    114.000000      5.000000
#
#           TOT_SALES     PACK_SIZE
# count  87750.000000  87749.000000
# mean       7.385557    182.900489
# std        2.530386     65.036788
# min        1.500000     70.000000
# 25%        5.700000    150.000000
# 50%        7.400000    170.000000
# ...

# %%
Total_Customer=89605

# %% [markdown]
# # **Avg no. of transaction per customers**

# %%
dataset.shape
# Out:
# (87750, 12)

# %%
avg_trns=87750/Total_Customer
print(avg_trns)
# Out:
# 0.979298030243848
